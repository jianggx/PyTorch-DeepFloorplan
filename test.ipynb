# %%
#matplotlib inline
import PIL
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
img = PIL.Image.open("dataset/cubicasa5k/val/colorful_967_room.png")
img = img.convert("RGB")
img = img.resize((512, 512))
numpy_img = np.array(img)
npstr = numpy_img.tostring()
img2 = np.fromstring(npstr, dtype=np.uint8).reshape(512, 512, 3)
print(img2.shape, np.unique(img2))
plt.imshow(img)
# Out:
# (512, 512, 3) [0 1 2 3 4 5 6 7]
# /tmp/ipykernel_7527/3664182223.py:5: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   npstr = numpy_img.tostring()
# /tmp/ipykernel_7527/3664182223.py:6: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   img2 = np.fromstring(npstr, dtype=np.uint8).reshape(512, 512, 3)
